# %%
from __future__ import print_function, division

import os
from keras.models import *
from keras.optimizers import SGD
from keras.losses import categorical_crossentropy
from keras.metrics import categorical_accuracy
from keras.callbacks import TensorBoard
from net import simpleconv3
from keras.preprocessing.image import ImageDataGenerator

# %%
def train_model(model, loss, metrics, optimizer, epochs=25):

    model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=metrics)
    model.summary()

    history = model.fit_generator(
        train_generator,
        steps_per_epoch=num_train_samples // batch_size,
        epochs=epochs,
        callbacks=callbacks,
        validation_data=val_generator,
        validation_steps=num_val_samples // batch_size)
    return model


if __name__ == '__main__':
    # dimensions of our images.
    img_width, img_height = 224, 224
    num_epochs = 10
    batch_size = 30

    train_data_dir = '../data/train/'
    validation_data_dir = '../data/val/'

    # this is the augmentation configuration we will use for training
    train_datagen = ImageDataGenerator(
        rescale=1. / 255,)
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True)
    # this is the augmentation configuration use for testing only rescaling
    val_datagen = ImageDataGenerator(rescale=1. / 255)

    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size)

    val_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size)

    num_train_samples = train_generator.samples
    num_val_samples = val_generator.samples

    tensorboard = TensorBoard(log_dir=('./logs'))
    callbacks = []
    callbacks.append(tensorboard)
    model = simpleconv3()
    loss = categorical_crossentropy
    metrics = [categorical_accuracy]
    optimizer = SGD(lr=0.001, decay=1e-6, momentum=0.9)

    model = train_model(model, loss, metrics,  optimizer, num_epochs)
# Out:
# Found 1350 images belonging to 3 classes.
# Found 150 images belonging to 3 classes.
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 12)      336
# _________________________________________________________________
# bn_conv1 (BatchNormalization (None, 112, 112, 12)      48
# _________________________________________________________________
# activation_4 (Activation)    (None, 112, 112, 12)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 56, 56, 24)        2616
# _________________________________________________________________
# bn_conv2 (BatchNormalization (None, 56, 56, 24)        96
# _________________________________________________________________
# activation_5 (Activation)    (None, 56, 56, 24)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 28, 28, 48)        10416
# _________________________________________________________________
# bn_conv3 (BatchNormalization (None, 28, 28, 48)        192
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 48)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 37632)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               4817024
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 4,831,115
# Trainable params: 4,830,947
# Non-trainable params: 168
# _________________________________________________________________
# Epoch 1/10
# 45/45 [==============================] - 4s 93ms/step - loss: 0.7894 - categorical_accuracy: 0.6489 - val_loss: 0.9694 - val_categorical_accuracy: 0.5533
# Epoch 2/10
# 45/45 [==============================] - 4s 78ms/step - loss: 0.3221 - categorical_accuracy: 0.8756 - val_loss: 0.9392 - val_categorical_accuracy: 0.5467
# Epoch 3/10
# 45/45 [==============================] - 4s 79ms/step - loss: 0.1170 - categorical_accuracy: 0.9659 - val_loss: 0.9302 - val_categorical_accuracy: 0.5733
# Epoch 4/10
# 45/45 [==============================] - 4s 83ms/step - loss: 0.0532 - categorical_accuracy: 0.9926 - val_loss: 0.6662 - val_categorical_accuracy: 0.7000
# Epoch 5/10
# 45/45 [==============================] - 4s 82ms/step - loss: 0.0261 - categorical_accuracy: 1.0000 - val_loss: 0.7892 - val_categorical_accuracy: 0.7200
# Epoch 6/10
# 45/45 [==============================] - 4s 88ms/step - loss: 0.0183 - categorical_accuracy: 1.0000 - val_loss: 0.4916 - val_categorical_accuracy: 0.7600
# Epoch 7/10
# 45/45 [==============================] - 4s 84ms/step - loss: 0.0127 - categorical_accuracy: 1.0000 - val_loss: 0.5365 - val_categorical_accuracy: 0.7067
# Epoch 8/10
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0104 - categorical_accuracy: 1.0000 - val_loss: 0.7073 - val_categorical_accuracy: 0.7467
# Epoch 9/10
# 45/45 [==============================] - 4s 86ms/step - loss: 0.0080 - categorical_accuracy: 1.0000 - val_loss: 0.5932 - val_categorical_accuracy: 0.7467
# Epoch 10/10
# 45/45 [==============================] - 4s 87ms/step - loss: 0.0069 - categorical_accuracy: 1.0000 - val_loss: 0.7004 - val_categorical_accuracy: 0.7400

# %%
# if not os.path.exists('models'):
#     os.mkdir('models')
# model_json = model.to_json()
# with open('models/model.json', 'w') as json_file:
#     json_file.write(model_json)
model.save('./model_simple.h5')
